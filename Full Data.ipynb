# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pickle

# %%
with open('diff_correct.pickle', 'rb') as f: # pickle the good file
    diff = pickle.load(f)
with open('goodbounds.pickle', 'rb') as f: # pickle the good file
    goodbounds = pickle.load(f)

# %%
pos_disp = pd.concat((goodbounds,diff), axis=1)

# %%
pos_disp
# Out:
#        timestep  boundry       F0x       F0y       F0z      Be1x      Be1y  \
# 1089    38445.0  5.35854  0.855397  2.684551  2.382174  4.776001  2.229836
# 1090    38445.5  5.35838  0.852697  2.688383  2.379858  4.776524  2.227836
# 1091    38446.0  5.35840  0.849922  2.692141  2.377623  4.777017  2.226150
# 1092    38446.5  5.35843  0.846982  2.695840  2.375344  4.777357  2.224666
# 1093    38447.0  5.35834  0.843784  2.699505  2.372861  4.777445  2.223281
# 1094    38447.5  5.35844  0.840552  2.703104  2.370488  4.777561  2.222214
# 1095    38448.0  5.35827  0.836919  2.706726  2.367763  4.777304  2.221165
# 1096    38448.5  5.35808  0.833355  2.710062  2.365115  4.776921  2.220356
# 1097    38449.0  5.35806  0.829601  2.713495  2.362402  4.776574  2.219796
# 1098    38449.5  5.35805  0.825726  2.716868  2.359647  4.776140  2.219448
# 1099    38450.0  5.35802  0.821458  2.720400  2.356623  4.775566  2.219274
# ...
